# %%
import pandas as pd

# %%
url = "https://finance.yahoo.com/quote/AAPL/history?p=AAPL"

# %%
data = pd.read_html(url , header=0)

# %%
data[0].head()
# Out:
#            Date    Open    High     Low  Close* Adj Close**     Volume
# 0  Mar 23, 2021  123.33  124.24  122.14  122.54      122.54   95467142
# 1  Mar 22, 2021  120.33  123.87  120.26  123.39      123.39  111711600
# 2  Mar 19, 2021  119.90  121.43  119.68  119.99      119.99  185023200
# 3  Mar 18, 2021  122.88  123.18  120.32  120.53      120.53  121229700
# 4  Mar 17, 2021  124.05  125.86  122.34  124.76      124.76  111437500

# %%
data[0].tail()
# Out:
#                                                   Date  \
# 96                                        Nov 04, 2020
# 97                                        Nov 03, 2020
# 98                                        Nov 02, 2020
# 99                                        Oct 30, 2020
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                   Open  \
# 96                                              114.14
# 97                                              109.66
# 98                                              109.11
# 99                                              111.06
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                   High  \
# 96                                              115.59
# 97                                              111.49
# 98                                              110.68
# 99                                              111.99
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                    Low  \
# 96                                              112.35
# 97                                              108.73
# 98                                              107.32
# 99                                              107.72
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                 Close*  \
# 96                                              114.95
# 97                                              110.44
# 98                                              108.77
# 99                                              108.86
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                            Adj Close**  \
# 96                                              114.58
# 97                                              110.09
# 98                                              108.42
# 99                                              108.51
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                 Volume
# 96                                           138235500
# 97                                           107624400
# 98                                           122866900
# 99                                           190272600
# 100  *Close price adjusted for splits.**Adjusted cl...

# %%
data[0]['Adj Close**'] = pd.to_numeric(data[0]['Adj Close**'], errors = "coerce")

# %%
data[0].tail()
# Out:
#                                                   Date  \
# 96                                        Nov 04, 2020
# 97                                        Nov 03, 2020
# 98                                        Nov 02, 2020
# 99                                        Oct 30, 2020
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                   Open  \
# 96                                              114.14
# 97                                              109.66
# 98                                              109.11
# 99                                              111.06
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                   High  \
# 96                                              115.59
# 97                                              111.49
# 98                                              110.68
# 99                                              111.99
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                    Low  \
# 96                                              112.35
# 97                                              108.73
# 98                                              107.32
# 99                                              107.72
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                 Close*  Adj Close**  \
# 96                                              114.95       114.58
# 97                                              110.44       110.09
# 98                                              108.77       108.42
# 99                                              108.86       108.51
# 100  *Close price adjusted for splits.**Adjusted cl...          NaN
#
#                                                 Volume
# 96                                           138235500
# 97                                           107624400
# 98                                           122866900
# 99                                           190272600
# 100  *Close price adjusted for splits.**Adjusted cl...

# %%
data[0].dropna(inplace=True)

# %%
data[0].tail()
# Out:
#             Date    Open    High     Low  Close*  Adj Close**     Volume
# 95  Nov 05, 2020  117.95  119.62  116.87  119.03       118.65  126387100
# 96  Nov 04, 2020  114.14  115.59  112.35  114.95       114.58  138235500
# 97  Nov 03, 2020  109.66  111.49  108.73  110.44       110.09  107624400
# 98  Nov 02, 2020  109.11  110.68  107.32  108.77       108.42  122866900
# 99  Oct 30, 2020  111.06  111.99  107.72  108.86       108.51  190272600

# %%
from datetime import datetime as dt

# %%
import locale

# %%
data[0]["Date2"] = [dt.strptime(i, "%b %d, %Y") for i in data[0]["Date"]]

# %%
data[0]["Date2"].head()
# Out:
# 0   2021-03-23
# 1   2021-03-22
# 2   2021-03-19
# 3   2021-03-18
# 4   2021-03-17
# Name: Date2, dtype: datetime64[ns]

# %%
data[0].head()
# Out:
#            Date    Open    High     Low  Close*  Adj Close**     Volume  \
# 0  Mar 23, 2021  123.33  124.24  122.14  122.54       122.54   95467142
# 1  Mar 22, 2021  120.33  123.87  120.26  123.39       123.39  111711600
# 2  Mar 19, 2021  119.90  121.43  119.68  119.99       119.99  185023200
# 3  Mar 18, 2021  122.88  123.18  120.32  120.53       120.53  121229700
# 4  Mar 17, 2021  124.05  125.86  122.34  124.76       124.76  111437500
#
#        Date2
# 0 2021-03-23
# 1 2021-03-22
# 2 2021-03-19
# 3 2021-03-18
# 4 2021-03-17

# %%
data[0].set_index("Date2", inplace=True)

# %%
data[0].head()
# Out:
#                     Date    Open    High     Low  Close*  Adj Close**  \
# Date2
# 2021-03-23  Mar 23, 2021  123.33  124.24  122.14  122.54       122.54
# 2021-03-22  Mar 22, 2021  120.33  123.87  120.26  123.39       123.39
# 2021-03-19  Mar 19, 2021  119.90  121.43  119.68  119.99       119.99
# 2021-03-18  Mar 18, 2021  122.88  123.18  120.32  120.53       120.53
# 2021-03-17  Mar 17, 2021  124.05  125.86  122.34  124.76       124.76
#
#                Volume
# Date2
# 2021-03-23   95467142
# 2021-03-22  111711600
# 2021-03-19  185023200
# 2021-03-18  121229700
# 2021-03-17  111437500

# %%
data[0]["Adj Close**"].dtype
# Out:
# dtype('float64')

# %%
data[0]["Adj Close**"].plot(title="AAPL Stock Price", grid=True)
# Out:
# <AxesSubplot:title={'center':'AAPL Stock Price'}, xlabel='Date2'>

# %%
data[0].to_csv("AAPL_Stock.csv")
